# %% [markdown]
# <a href="https://colab.research.google.com/github/NadilaAmaliaaa/PCVK_GANJIL_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
#Membuat list menyimpan URL image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://asset.kompas.com/crops/w1IfBCEe0mIlxAm8xYe95HpLoOM=/0x0:1000x667/750x500/data/photo/2022/05/12/627c98f83f42a.jpg"]

#baca dan tampilkan img
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggixlebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggixlebar =  250  x  375
# <PIL.Image.Image image mode=RGB size=375x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal
for y in range(lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis diagonal
for x in range(tinggi):
    y = int((lebar / tinggi) * x)
    image_3[x, y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# - Google Colab lebih mudah digunakan karena tidak perlu menginstall library satu-satu dan dapat terintegrasi langsung dengan repository github
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - numpy = digunakan untuk manipulasi array multidimensi (seperti matriks), operasi matematika, dan linear algebra.
# - pandas = digunakan untuk membaca data dari berbagai format (CSV, Excel, dll.), membersihkan data, dan melakukan analisis statistik.
# - cv2 = Menyediakan berbagai fungsi untuk membaca, menulis, mengubah, dan menganalisis gambar.
# - cv2_imshow = untuk menampilkan hasil pemrosesan gambar secara visual.
# - io = Dalam konteks pemrosesan gambar, sering digunakan untuk membaca gambar dari file atau URL.
# - transform = untuk berbagai teknik transformasi (misalnya, rotasi, scaling, shearing) diterapkan pada gambar untuk mengubah representasinya.
# - image = merupakan library untuk manipulasi gambar.
# - matplotlib.pylab = Submodul dari Matplotlib, menyediakan fungsi-fungsi untuk membuat plot dan visualisasi data.
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ![1.PNG](data:image/png;base64,...)
# - Untuk meresize gambar agar berukuran setengah dari ukuran aslinya
# 4. Perhatikan potongan kode progam berikut :
#
# ![image.png](data:image/png;base64,...)
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# - Untuk mengubah pixel menjadi warna putih yang RGB nya adalah [255,255,255] sehingga memberikan garis horizontal pada tengah gambar
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# - Pixel adalah elemen dasar penyusun gambar, sedangkan resolusi adalah ukuran jumlah piksel dalam gambar. Semakin tinggi resolusi, semakin banyak piksel, dan semakin detail gambar tersebut.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# #membuat garis vertikal
# for x in range(tinggi):
#   image_3[x,int((lebar)/2)] = [255,255,255]

image_3[:,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_3[:, y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
